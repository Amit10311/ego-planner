# %% [markdown]
# # UAV Simulator

# %% [markdown]
# ## 1 LOCAL SESNING
#
# 1. DEPTH RENDER
# 2. PCL RENDER

# %% [markdown]
# ##  2 UTILITIES
#
# 1. cmake utilis
# 2. multi_pap_server
# 3. odom_visulaization
# 4. pose_utilis
# 5. qaudrotor_msgs
# 6. rviz_plugins
# 7. waypoint_generator

# %% [markdown]
# ## 3 MAP GENERATOR
#
# 1. random forest sensing

# %% [markdown]
# ## 4 MOCK MAPPING
#
# 1. random map
# 2. maps
# 3. Noise reduce

# %% [markdown]
# Used create own environment. Can Learn about potncloud2 , nav_msgs odometry, pcl_conversions, point cloud , pcl libraraies

# %% [markdown]
# ## 5 SO3 CONTROL
#
# 1. control example
# 2. control nodelet
# 3. SO3 control

# %% [markdown]
# You can execute

# %%
roslaunch so3_quadrotor_simulator simulator_example.launch

# %% [markdown]
# to run a simple example in

# %%
ego-planner/src/uav_simulator/so3/control/src/control_example.cpp.

# %%
rosrun so3_control control_example

# %%
Position Control to (2,0,1) meters
Velocity Control to (-1,0,0) meters/second
Accelleration Control to (1,0,0) meters/second^2

# %% [markdown]
# ## 6 Qaudrotor Simulator
#
# 1. Dynamics
# 2. test Dynamics

# %% [markdown]
# Step 3. Compile,

# %%
cd ego-planner
catkin_make -DCMAKE_BUILD_TYPE=Release

# %% [markdown]
# Step 4. Run.
#
# In a terminal at the ego-planner/ folder, open the rviz for visuallization and interactions

# %%
source devel/setup.bash
roslaunch ego_planner rviz.launch

# %% [markdown]
# In another terminal at the ego-planner/, run the planner in simulation by

# %%
source devel/setup.bash
roslaunch ego_planner run_in_sim.launch
